# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("student_clustering.csv")
df
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]>

# %%
plt.scatter(df['cgpa'],df['iq'])
plt.show()

# %%
wcss=[]
for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit_predict(df)
    wcss.append(model.inertia_)
wcss
# Out:
# [29957.898288,
#  4184.14127,
#  2503.397581,
#  681.96966,
#  530.4298616986188,
#  427.9627769877214,
#  406.67165620833333,
#  260.1227011760185,
#  208.08330910184583,
#  190.49950394753355]

# %%
plt.plot(range(1,11),wcss)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=df.to_numpy()
x
# Out:
# array([[  5.13,  88.  ],
#        [  5.9 , 113.  ],
#        [  8.36,  93.  ],
#        [  8.27,  97.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  8.41,  98.  ],
#        [  8.8 , 115.  ],
#        [  5.79, 110.  ],
#        [  8.09,  94.  ],
#        [  4.6 ,  86.  ],
#        [  6.1 , 110.  ],
#        [  8.16,  97.  ],
#        [  5.  ,  88.  ],
#        [  5.71, 108.  ],
#        [  8.31,  95.  ],
#        [  5.5 , 111.  ],
#        [  7.87,  91.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  7.47,  98.  ],
#        [  4.86,  86.  ],
#        [  7.78,  92.  ],
#        [  4.78,  87.  ],
#        [  4.96,  88.  ],
#        [  7.93,  98.  ],
#        [  4.86,  87.  ],
#        [  9.18, 119.  ],
#        [  8.04,  94.  ],
#        [  5.43, 106.  ],
#        [  8.86, 117.  ],
#        [  6.01, 112.  ],
#        [  8.83, 118.  ],
#        [  5.32, 106.  ],
#        [  7.77,  96.  ],
#        [  8.  ,  96.  ],
#        [  8.56, 118.  ],
# ...

# %%
x=df.iloc[:,:].values
x
# Out:
# array([[  5.13,  88.  ],
#        [  5.9 , 113.  ],
#        [  8.36,  93.  ],
#        [  8.27,  97.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  8.41,  98.  ],
#        [  8.8 , 115.  ],
#        [  5.79, 110.  ],
#        [  8.09,  94.  ],
#        [  4.6 ,  86.  ],
#        [  6.1 , 110.  ],
#        [  8.16,  97.  ],
#        [  5.  ,  88.  ],
#        [  5.71, 108.  ],
#        [  8.31,  95.  ],
#        [  5.5 , 111.  ],
#        [  7.87,  91.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  7.47,  98.  ],
#        [  4.86,  86.  ],
#        [  7.78,  92.  ],
#        [  4.78,  87.  ],
#        [  4.96,  88.  ],
#        [  7.93,  98.  ],
#        [  4.86,  87.  ],
#        [  9.18, 119.  ],
#        [  8.04,  94.  ],
#        [  5.43, 106.  ],
#        [  8.86, 117.  ],
#        [  6.01, 112.  ],
#        [  8.83, 118.  ],
#        [  5.32, 106.  ],
#        [  7.77,  96.  ],
#        [  8.  ,  96.  ],
#        [  8.56, 118.  ],
# ...

# %%
model=KMeans(n_clusters=4)
y=model.fit_predict(x)
y
# Out:
# array([3, 2, 1, 1, 2, 2, 1, 0, 2, 1, 3, 2, 1, 3, 2, 1, 2, 1, 2, 2, 1, 3,
#        1, 3, 3, 1, 3, 0, 1, 2, 0, 2, 0, 2, 1, 1, 0, 2, 3, 2, 3, 1, 1, 3,
#        0, 0, 1, 2, 0, 2, 3, 3, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 1, 0, 3, 0,
#        1, 3, 2, 1, 2, 0, 1, 3, 2, 0, 2, 0, 3, 1, 1, 0, 2, 3, 0, 3, 0, 2,
#        0, 2, 0, 0, 1, 3, 1, 1, 0, 1, 3, 0, 2, 3, 3, 0, 3, 3, 1, 3, 0, 0,
#        1, 0, 2, 2, 1, 0, 1, 2, 0, 3, 3, 2, 1, 0, 1, 3, 1, 2, 3, 1, 1, 2,
#        3, 3, 2, 0, 2, 3, 1, 1, 1, 3, 2, 3, 3, 0, 3, 0, 2, 3, 0, 3, 0, 0,
#        3, 1, 2, 0, 2, 1, 3, 0, 2, 1, 0, 3, 2, 3, 3, 0, 0, 2, 0, 3, 3, 1,
#        0, 2, 3, 0, 0, 2, 2, 2, 1, 3, 1, 1, 0, 2, 1, 1, 3, 3, 1, 3, 0, 2,
#        2, 0], dtype=int32)

# %%
df['classes']=y
df
# Out:
#      cgpa   iq  classes
# 0    5.13   88        3
# 1    5.90  113        2
# 2    8.36   93        1
# 3    8.27   97        1
# 4    5.45  110        2
# ..    ...  ...      ...
# 195  4.68   89        3
# 196  8.57  118        0
# 197  5.85  112        2
# 198  6.23  108        2
# 199  8.82  117        0
#
# [200 rows x 3 columns]

# %%
x[y==0,0]
# Out:
# array([8.8 , 9.18, 8.86, 8.83, 8.56, 8.96, 8.78, 8.45, 8.79, 8.81, 8.88,
#        9.07, 8.92, 8.75, 8.71, 8.86, 9.3 , 9.01, 8.97, 9.  , 8.76, 8.78,
#        9.23, 9.03, 9.13, 8.91, 8.98, 9.03, 8.86, 8.89, 8.97, 8.72, 8.93,
#        8.58, 8.94, 8.6 , 8.77, 8.81, 8.54, 8.97, 8.91, 8.68, 9.06, 8.9 ,
#        8.94, 8.91, 8.91, 8.95, 8.57, 8.82])

# %%
x[y==0,1]
# Out:
# array([115., 119., 117., 118., 118., 116., 116., 119., 116., 115., 115.,
#        117., 118., 113., 116., 118., 117., 121., 116., 117., 117., 117.,
#        114., 118., 118., 119., 118., 118., 117., 118., 117., 119., 118.,
#        118., 117., 117., 117., 116., 118., 119., 117., 119., 120., 117.,
#        115., 115., 117., 116., 118., 117.])

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='Red',label ='category 1.0.1')
plt.scatter(x[y==1,0],x[y==1,1],color='Blue',label='category 1')
plt.scatter(x[y==2,0],x[y==2,1],color='Green',label='category 2')
plt.scatter(x[y==3,0],x[y==3,1],color='Yellow',label='category 3')
plt.title('K-Mean of student data')
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.legend()
plt.show()

# %%
from sklearn.datasets import make_blobs

# Define the centroids and standard deviations
centroids = [(-5, -5, 5), (5, 5, -5), (2.5, -2.5, 4), (-2.4, 2.5, -4)]
cluster_std = [1, 1, 1, 1]

# Generate the dataset
X, Y = make_blobs(n_samples=200, cluster_std=cluster_std, centers=centroids, n_features=3)

# %%
X,Y
# Out:
# (array([[ 3.52022909, -4.4247018 ,  4.34080324],
#         [ 3.33475893, -1.97876879,  3.72888693],
#         [-2.9236936 ,  1.95458746, -5.28710332],
#         [-3.86532537, -3.53524793,  3.26409871],
#         [ 0.95413527, -0.01349803,  4.71739655],
#         [-3.36439863, -5.18899904,  5.19590443],
#         [-3.11728982,  2.99733014, -4.1805419 ],
#         [-2.69924754,  1.54201811, -3.74830397],
#         [ 4.55379099,  5.01551558, -3.99184214],
#         [ 3.05690811, -2.74945267,  4.14860951],
#         [ 4.26130956,  5.26121579, -4.0397214 ],
#         [ 3.82272924,  5.57841372, -3.64098554],
#         [-5.88198763, -5.85685417,  4.40854165],
#         [ 2.16048297, -3.35774118,  3.9011443 ],
#         [ 1.64335717, -5.2727722 ,  3.16172045],
#         [-3.52846265, -5.25059832,  3.72771362],
#         [-4.12433725, -5.49917541,  7.02591151],
#         [ 0.62120628, -4.75253621,  4.90528544],
#         [ 6.24977437,  5.43896591, -4.32173281],
# ...
